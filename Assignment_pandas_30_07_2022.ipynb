# %% [raw]
# 1.find out their avg rating on weekly basis keepthis in mind that they take 2 days of leave
# 2.Total working days for each agent
# 3.total query that you have taken
# 4.tital feedback that you have received
# 5.agent name who has avg fating between 3.5 to 4
# 6.Agent name who has rating less than 3.5
# 7.rating more than 4.5
# 8.how many agents got rating more than 4.5
# 9.avg weekly response time for each agent
# 10.avg weekly resolution time for eah agent
# 11.list of all agent names
# 12.% of chat on which they have received feedback
# 13.total contribution hour for each and every agents weekly basis
# 14.total% of active hour for a month
# sunny.savita@ineuron.ai,sudhanshu@ineuron.ai

# %% [markdown]
# # 1.find out their avg rating on weekly basis keepthis in mind that they take 2 days of leave

# %%
import pandas as pd

# %%
df_agentLog=pd.read_csv(r"C:\Users\vijay\Downloads\AgentLogingReport (1).csv")

# %%
df_agentPerform=pd.read_csv(r"C:\Users\vijay\Downloads\AgentPerformance (1).csv")

# %%
df_agentLog
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 6 columns]

# %%
df_agentPerform
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
df_agentPerform['Converted_Date']=pd.to_datetime(df_agentPerform['Date'])

# %%
df_agentPerform['Converted_Date']
# Out:
# 0      2022-07-30
# 1      2022-07-30
# 2      2022-07-30
# 3      2022-07-30
# 4      2022-07-30
#           ...
# 2155   2022-07-01
# 2156   2022-07-01
# 2157   2022-07-01
# 2158   2022-07-01
# 2159   2022-07-01
# Name: Converted_Date, Length: 2160, dtype: datetime64[ns]

# %%
df_agentPerform
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
df_agentPerform['week']=df_agentPerform['Converted_Date'].dt.week
# Out:
# C:\Users\vijay\AppData\Local\Temp/ipykernel_24116/1892827156.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df_agentPerform['week']=df_agentPerform['Converted_Date'].dt.week

# %%
df_agentPerform
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
# from datetime import timedelta
# df_agentPerform['week_start']=df_agentPerform['Converted_Date'].dt.to_period('W').apply(lambda x:x.start_time)
# df_agentPerform['week_start']=df_agentPerform['week_start']+timedelta(days=2)

# %%
df_agentPerform['week_start_new']=df_agentPerform['Converted_Date']-pd.offsets.Week(weekday=4)
df_agentPerform['week_end_new']=df_agentPerform['week_start_new']+pd.offsets.Week(weekday=3)
df_agentPerform['week']=df_agentPerform['week_start_new'].astype(str) + "-" + df_agentPerform['week_end_new'].astype(str)
#df_agentPerform['week']=df_agentPerform.apply(lambda x:"%s - %s"%(x['week_start_new'],x['week_end_new']),axis=1)
#df_agentPerform['week']=pd.to_datetime(df_agentPerform['week'])

# %%
import numpy as np

# %%
df_agentPerform['Average Rating'].replace(0,np.nan,inplace=True)

# %%
df_weekly_rating=df_agentPerform.groupby(['Agent Name',pd.Grouper(key='week_start_new',freq='W')])['Average Rating'].agg(weeklyAvgRating='mean')

# %%
df_weekly_rating

# %%
df_weekly_rating.to_excel(r"C:\Users\vijay\Downloads\AgentWeeklyPerformance_new4.xlsx")

# %%
#df_agentPerform.drop(['weekly_StartDate'],axis=1,inplace=True)

# %% [markdown]
# # 2.Total working days for each agent

# %%
df_agentlogin=pd.read_csv(r"C:\Users\vijay\Downloads\AgentLogingReport (1).csv")

# %%
#df_AgentAttendance=df_agentlogin.groupby('Agent')['Date'].count()
df_AgentAttendance=df_agentlogin.groupby('Agent')['Date'].agg(TotalWorkingDays='count')

# %%
df_AgentAttendance
# Out:
#                         TotalWorkingDays
# Agent
# Aditya Shinde                          1
# Aditya_iot                             9
# Amersh                                 4
# Ameya Jain                            10
# Ankitjha                               4
# Anurag Tiwari                         37
# Aravind                               10
# Ayushi Mishra                         18
# Bharath                                9
# Boktiar Ahmed Bappy                   17
# Chaitra K Hiremath                    13
# Deepranjan Gupta                      58
# Dibyanshu                            208
# Harikrishnan Shaji                    23
# Hrisikesh Neogi                       37
# Hyder Abbas                            2
# Ineuron Intelligence                   1
# Ishawant Kumar                        49
# Jawala Prakash                        16
# Jaydeep Dixit                         11
# Khushboo Priya                        18
# Madhulika G                           17
# ...

# %%
df_AgentAttendance.to_excel(r"C:\Users\vijay\Downloads\Agentattendance1.xlsx")

# %% [markdown]
# # 3.Total query that you have taken

# %%
df_totalQueries=df_agentPerform.groupby('Agent Name')['Total Chats'].sum()

# %%
df_totalQueries.to_excel(r"C:\Users\vijay\Downloads\totalQueries1.xlsx")

# %% [markdown]
# # 4.Total feedback that you have received

# %%
df_agentPerform.groupby('Agent Name')['Total Feedback'].agg(TotalFeeedBack='sum')
# Out:
#                TotalFeeedBack
# Agent Name
# Abhishek                    0
# Aditya                      0
# Aditya Shinde             153
# Aditya_iot                131
# Amersh                      0
# ...                       ...
# Uday Mishra                 0
# Vasanth P                   0
# Vivek                      20
# Wasim                     284
# Zeeshan                   335
#
# [70 rows x 1 columns]

# %% [markdown]
# # 5.Agent name who has avg rating between 3.5 to 4

# %%
df_AgentAvgRating=df_agentPerform.groupby('Agent Name')['Average Rating'].agg(AvgRating='mean')

# %%
df_AgentAvgRating[(df_AgentAvgRating['AvgRating'] >3.5) & (df_AgentAvgRating['AvgRating'] <4)]
# Out:
#             AvgRating
# Agent Name
# Mithun S     3.931667

# %% [markdown]
# # 6.Agent name who has rating less than 3.5

# %%
df_AgentAvgRating[df_AgentAvgRating['AvgRating'] <3.5]
# Out:
#                AvgRating
# Agent Name
# Anirudh         3.225000
# Anurag Tiwari   2.750000
# Ashad Nasim     2.500000
# Mahak           3.000000
# Maneesh         2.500000
# Mukesh Rao      2.556667
# Tarun           1.500000
# Vivek           3.004000

# %% [markdown]
# # 7.Agent name who has rating more than 4.5

# %%
df_AgentAvgRating[df_AgentAvgRating['AvgRating'] >4.5]
# Out:
#                     AvgRating
# Agent Name
# Aditya Shinde        4.500833
# Aravind              4.674286
# Bharath              4.711053
# Jaydeep Dixit        4.524286
# Mukesh               4.645000
# Prateek _iot         4.571875
# Saikumarreddy N      4.570000
# Shivananda Sonwane   4.535000
# Shubham Sharma       4.607619
# Sudhanshu Kumar      5.000000
# Suraj S Bilgi        4.680000

# %%
df_agentPerform['Average Response Time'].value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24116/3353490915.py in <module>
# ----> 1 df_agentPerform['Average Response Time'].value
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value'

# %% [markdown]
# # 9.avg weekly response time for each agent

# %%
df_agentPerform['AverageRespTime_int']=pd.to_datetime(df_agentPerform['Average Response Time']).apply(lambda x:x.value)

# %%
#df_agentPerform.to_excel(r"C:\Users\vijay\Downloads\Agent_perform_response_int.xlsx")

# %%
df_agentPerform['AverageRespTime_int'].replace(0,'np.Nan')
# Out:
# 0       1660608038000000000
# 1       1660608075000000000
# 2       1660608030000000000
# 3       1660608064000000000
# 4       1660608071000000000
#                ...
# 2155    1660608000000000000
# 2156    1660608000000000000
# 2157    1660608000000000000
# 2158    1660608000000000000
# 2159    1660608000000000000
# Name: AverageRespTime_int, Length: 2160, dtype: int64

# %%
df_avgWeeklyResponse=df_agentPerform.groupby(['Agent Name',pd.Grouper(key='week_start_new',freq='W')])['AverageRespTime_int'].agg(weeklyAvgResponse='mean')

# %%
df_avgWeeklyResponse
# Out:
#                            weeklyAvgResponse
# Agent Name week_start_new
# Abhishek   2022-06-26           1.660522e+18
#            2022-07-03           1.660522e+18
#            2022-07-10           1.660522e+18
#            2022-07-17           1.660522e+18
#            2022-07-24           1.660522e+18
# ...                                      ...
# Zeeshan    2022-07-03           1.660522e+18
#            2022-07-10           1.660522e+18
#            2022-07-17           1.660522e+18
#            2022-07-24           1.660522e+18
#            2022-07-31           1.660522e+18
#
# [420 rows x 1 columns]

# %%
df_avgWeeklyResponse=pd.to_datetime(df_avgWeeklyResponse['weeklyAvgResponse']).dt.time

# %%
df_avgWeeklyResponse.to_excel(r"C:\Users\vijay\Downloads\Agent_avgWeeklyResponse.xlsx")

# %% [markdown]
# # 10.avg weekly resolution time for each agent

# %%
df_agentPerform['AverageReslTime_int']=pd.to_datetime(df_agentPerform['Average Resolution Time']).apply(lambda x:x.value)

# %%
df_avgWeeklyResolution=df_agentPerform.groupby(['Agent Name',pd.Grouper(key='week_start_new',freq='W')])['AverageReslTime_int'].agg(weeklyAvgResolution='mean')

# %%
df_avgWeeklyResolution
# Out:
#                            weeklyAvgResolution
# Agent Name week_start_new
# Abhishek   2022-06-26             1.660608e+18
#            2022-07-03             1.660608e+18
#            2022-07-10             1.660608e+18
#            2022-07-17             1.660608e+18
#            2022-07-24             1.660608e+18
# ...                                        ...
# Zeeshan    2022-07-03             1.660608e+18
#            2022-07-10             1.660609e+18
#            2022-07-17             1.660609e+18
#            2022-07-24             1.660609e+18
#            2022-07-31             1.660608e+18
#
# [420 rows x 1 columns]

# %%
df_avgWeeklyResolution=pd.to_datetime(df_avgWeeklyResolution['weeklyAvgResolution']).dt.time
# Out:
# Agent Name  week_start_new
# Abhishek    2022-06-26               00:00:00
#             2022-07-03               00:00:00
#             2022-07-10               00:00:00
#             2022-07-17               00:00:00
#             2022-07-24               00:00:00
#                                    ...
# Zeeshan     2022-07-03               00:05:23
#             2022-07-10        00:13:47.714285
#             2022-07-17        00:12:58.857142
#             2022-07-24               00:13:55
#             2022-07-31               00:00:00
# Name: weeklyAvgResolution, Length: 420, dtype: object

# %% [markdown]
# # 11.list of all agent names

# %%
df_agentPerform['Agent Name'].unique()
# Out:
# array(['Prerna Singh', 'Nandani Gupta', 'Ameya Jain', 'Mahesh Sarade',
#        'Swati ', 'Mukesh ', 'Saikumarreddy N', 'Sanjeev Kumar',
#        'Shubham Sharma', 'Nishtha Jain', 'Manjunatha A', 'Khushboo Priya',
#        'Suraj S Bilgi', 'Harikrishnan Shaji', 'Hrisikesh Neogi',
#        'Shivan K', 'Sowmiya Sivakumar', 'Madhulika G', 'Mithun S',
#        'Hitesh Choudhary', 'Sanjeevan ', 'Anirudh ', 'Shiva Srivastava',
#        'Dibyanshu ', 'Ashish ', 'Uday Mishra', 'Aditya Shinde',
#        'Jayant Kumar', 'Aditya_iot ', 'Prabir Kumar Satapathy',
#        'Saurabh Shukla', 'Wasim ', 'Samprit ', 'Maitry ', 'Abhishek ',
#        'Rishav Dash', 'Aravind ', 'Tarun ', 'Muskan Garg', 'Ankit Sharma',
#        'Bharath ', 'Ashad Nasim', 'Vasanth P', 'Aditya ', 'Amersh ',
#        'Sandipan Saha', 'Ineuron Intelligence ', 'Mahak ', 'Mukesh Rao ',
#        'Zeeshan ', 'Anurag Tiwari', 'Ankitjha ', 'Saif Khan',
#        'Jaydeep Dixit', 'Sudhanshu Kumar', 'Maneesh ', 'Hyder Abbas',
# ...

# %% [markdown]
# # 12.Percentage of chat on which they have received feedback

# %%
df_agentPerform
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
df_agentChatFBAgg=df_agentPerform.groupby('Agent Name').agg({'Total Chats':'sum','Total Feedback':'sum'})

# %%
df_agentChatFBAgg['perchatFB']=(df_agentChatFBAgg['Total Feedback']/df_agentChatFBAgg['Total Chats'])*100

# %%
df_agentChatFBAgg
# Out:
#                Total Chats  Total Feedback  perchatFB
# Agent Name
# Abhishek                 0               0        NaN
# Aditya                   0               0        NaN
# Aditya Shinde          277             153  55.234657
# Aditya_iot             231             131  56.709957
# Amersh                   0               0        NaN
# ...                    ...             ...        ...
# Uday Mishra              0               0        NaN
# Vasanth P                0               0        NaN
# Vivek                   44              20  45.454545
# Wasim                  433             284  65.588915
# Zeeshan                542             335  61.808118
#
# [70 rows x 3 columns]

# %% [markdown]
# # 13.total contribution hour for each and every agents weekly basis

# %%
df_agentlogin=pd.read_csv(r"C:\Users\vijay\Downloads\AgentLogingReport (1).csv")

# %%
df_agentlogin['week_start_new']=pd.to_datetime(df_agentlogin['Date'])-pd.offsets.Week(weekday=4)

# %%
df_agentlogin['week_end_new']=df_agentlogin['week_start_new']+pd.offsets.Week(weekday=3)

# %%
df_agentlogin
# Out:
#      SL No               Agent       Date Login Time Logout Time  Duration  \
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39  02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16  00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07  02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35  00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52  01:08:36
# ..     ...                 ...        ...        ...         ...       ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28  05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32  06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55  05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33  05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  10:08:20
#
#     week_start_new week_end_new         Duration_Int
# ...

# %%
df_agentlogin['Duration_Int']=pd.to_datetime(df_agentlogin['Duration']).apply(lambda x:x.value)

# %%
df_weeklyConDuration=df_agentlogin.groupby(['Agent',pd.Grouper(key='week_start_new',freq='W')])['Duration_Int'].agg(weeklyContDur='sum')

# %%
df_weeklyConDuration['weeklyContDur']=pd.to_datetime(df_weeklyConDuration['weeklyContDur']).dt.time

# %%
df_weeklyConDuration['weeklyContDur'].fillna(0,inplace=True)

# %%
df_weeklyConDuration
# Out:
#                              weeklyContDur
# Agent         week_start_new
# Aditya Shinde 2022-07-24          00:02:10
# Aditya_iot    2022-07-17          06:05:43
#               2022-07-24                 0
# Amersh        2022-07-24          03:03:50
# Ameya Jain    2022-07-17          11:12:49
# ...                                    ...
# Tarun         2022-06-26          10:08:20
# Wasim         2022-07-17                 0
#               2022-07-24                 0
# Zeeshan       2022-07-17          18:19:10
#               2022-07-24                 0
#
# [109 rows x 1 columns]

# %%
df_weeklyConDuration.to_excel(r"C:\Users\vijay\Downloads\weeklyConDuration2.xlsx")

# %% [markdown]
# # 14.total% of active hour for a month

# %%
#from pandas.tseries.offsets import MonthBegin

# %%
#pd.datetime(df_agentlogin['Date'])- MonthBegin(n=1)

# %%
df_agentlogin['month']=pd.to_datetime(df_agentlogin['Date']).dt.month

# %%
df_agentlogin
# Out:
#      SL No               Agent       Date Login Time Logout Time  Duration  \
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39  02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16  00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07  02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35  00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52  01:08:36
# ..     ...                 ...        ...        ...         ...       ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28  05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32  06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55  05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33  05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  10:08:20
#
#     week_start_new week_end_new         Duration_Int  month
# ...

# %%
df_Agent_monthlycont=df_agentlogin.groupby(['Agent','month']).agg(monthlycon=('Duration_Int','sum'))

# %%
df_Agent_monthlycont
# Out:
#                                 monthlycon
# Agent                  month
# Aditya Shinde          7      1.660608e+18
# Aditya_iot             7      1.494553e+19
# Amersh                 7      6.642443e+18
# Ameya Jain             7      1.660623e+19
# Ankitjha               7      6.642440e+18
# Anurag Tiwari          7      6.144251e+19
# Aravind                7      1.660617e+19
# Ayushi Mishra          7      2.989108e+19
# Bharath                7      1.494565e+19
# Boktiar Ahmed Bappy    7      2.823048e+19
# Chaitra K Hiremath     7      2.158803e+19
# Deepranjan Gupta       7      9.631565e+19
# Dibyanshu              7      3.454067e+20
# Harikrishnan Shaji     7      3.819418e+19
# Hrisikesh Neogi        7      6.144270e+19
# Hyder Abbas            7      3.321217e+18
# Ineuron Intelligence   7      1.660613e+18
# Ishawant Kumar         7      8.136998e+19
# Jawala Prakash         7      2.656990e+19
# Jaydeep Dixit          7      1.826682e+19
# ...

# %%
df_Agent_monthlycont['monthlycon']=pd.to_datetime(df_Agent_monthlycont['monthlycon']).dt.time

# %%
df_Agent_monthlycont
# Out:
#                                    monthlycon
# Agent                  month
# Aditya Shinde          7             00:02:10
# Aditya_iot             7                  NaT
# Amersh                 7             03:03:50
# Ameya Jain             7                  NaT
# Ankitjha               7      02:16:00.999999
# Anurag Tiwari          7                  NaT
# Aravind                7                  NaT
# Ayushi Mishra          7                  NaT
# Bharath                7                  NaT
# Boktiar Ahmed Bappy    7                  NaT
# Chaitra K Hiremath     7                  NaT
# Deepranjan Gupta       7                  NaT
# Dibyanshu              7                  NaT
# Harikrishnan Shaji     7                  NaT
# Hrisikesh Neogi        7                  NaT
# Hyder Abbas            7             00:23:17
# Ineuron Intelligence   7             01:26:55
# Ishawant Kumar         7                  NaT
# Jawala Prakash         7                  NaT
# ...

# %%
df_Agent_monthlycont['monthlycon'].fillna(0,inplace=True)

# %%
df_Agent_monthlycont
# Out:
#                                    monthlycon
# Agent                  month
# Aditya Shinde          7             00:02:10
# Aditya_iot             7                    0
# Amersh                 7             03:03:50
# Ameya Jain             7                    0
# Ankitjha               7      02:16:00.999999
# Anurag Tiwari          7                    0
# Aravind                7                    0
# Ayushi Mishra          7                    0
# Bharath                7                    0
# Boktiar Ahmed Bappy    7                    0
# Chaitra K Hiremath     7                    0
# Deepranjan Gupta       7                    0
# Dibyanshu              7                    0
# Harikrishnan Shaji     7                    0
# Hrisikesh Neogi        7                    0
# Hyder Abbas            7             00:23:17
# Ineuron Intelligence   7             01:26:55
# Ishawant Kumar         7                    0
# Jawala Prakash         7                    0
# ...

# %%
#df['month']=df_agentlogin['Date'].to_numpy().astype('datetime64[M]')

# %%
df_Agent_monthlycont.to_excel(r"C:\Users\vijay\Downloads\Agent_monthlycont.xlsx")

# %%
df_monthlyConDuration=df_agentlogin.groupby(['Agent',pd.Grouper(key='week_start_new',freq='M')])['Duration_Int'].agg(monthlyContDur='sum')

# %%
df_monthlyConDuration.to_excel(r"C:\Users\vijay\Downloads\monthlyConDuration.xlsx")
